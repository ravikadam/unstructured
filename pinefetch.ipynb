# %%
import pandas as pd
from sentence_transformers import SentenceTransformer

# %%
from pinecone import Pinecone, ServerlessSpec
pc = Pinecone(api_key="pcsk_ToN8G_48StUwjtuiqLt5XGSXFLaG8LJWAwpev86SU1Xu4GgiZbAo9LZA2tNfAJSHmj52S")

# %%
index_name = "oracledocs"
index = pc.Index(index_name)

# %%
minilm_model = SentenceTransformer('intfloat/multilingual-e5-large')
# Out:
# modules.json:   0%|          | 0.00/387 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/160k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/57.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/690 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/2.24G [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/418 [00:00<?, ?B/s]
# sentencepiece.bpe.model:   0%|          | 0.00/5.07M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/17.1M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/280 [00:00<?, ?B/s]
# 1_Pooling/config.json:   0%|          | 0.00/201 [00:00<?, ?B/s]

# %%
def fetchManual(q,k):
    query_vector = minilm_model.encode(q).tolist()
    # To get top 5 related contents 
    related_contents = index.query(
    vector=query_vector,
    top_k=k,
    namespace='ns1',
    include_metadata=True,
    filter={'source':'Manual'})
    return related_contents

# %%
fetchManual("Request New Position\nRequest Position Change",10)
# Out:
# {'matches': [{'id': 'm736',
#               'metadata': {'filetype': 'PPM',
#                            'id': 'm736',
#                            'is_continuation': True,
#                            'languages': ['eng'],
#                            'last_modified': '2024-11-17T03:24:43',
#                            'page_number': 101.0,
#                            'source': 'Manual',
#                            'text': 'Talent Community Flow Apply Flow Request '
#                                    'Information Flow'},
#               'score': 0.874185324,
#               'values': []},
#              {'id': 'm715',
#               'metadata': {'filetype': 'PPM',
#                            'id': 'm715',
#                            'is_continuation': True,
#                            'languages': ['eng'],
#                            'last_modified': '2024-11-17T03:24:43',
#                            'page_number': 98.0,
#                            'source': 'Manual',
# ...

# %%
OPENAI_API_KEY='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'

# %%
pd.read_excel('./data/Inputfiles/HCM_Talent_Management_Recruit_Input.xlsx')
# Out:
#                   Business Process  \
# 0              Position Management
# 1                              NaN
# 2                              NaN
# 3                              NaN
# 4                              NaN
# 5                              NaN
# 6                              NaN
# 7                              NaN
# 8                              NaN
# 9                              NaN
# 10            Post Job Requisition
# 11                             NaN
# 12                             NaN
# 13                             NaN
# 14                             NaN
# 15                             NaN
# 16                             NaN
# 17                             NaN
# 18                             NaN
# 19                             NaN
# 20                             NaN
# 21                             NaN
# 22          Create Job Requisition
# 23                             NaN
# 24                             NaN
# ...
